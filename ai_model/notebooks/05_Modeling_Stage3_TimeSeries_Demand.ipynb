# %% [markdown]
# # 05. 사용주기 AI 3단계 월별 수요 예측
#
# 3단계는 자산별 총수명 예측 모델을 직접 교체하는 단계가 아니라, 월별 고장/처분 수요를 시계열 관점에서 검증하는 보조 실험이다.
#
# - SARIMAX 기반 월별 총 수요 예측
# - XGBoost lag feature 기반 월별 총 수요 예측
# - SARIMAX + XGBoost 잔차 보정
# - 2단계 최상위 자산 모델이 만드는 월별 수요 집계 검증
#
# 실행 결과는 `ai_model/experiments/runs/*_stage3_timeseries_demand`에 저장된다.

# %%
# %run ai_model/experiments/run_stage3_timeseries_demand.py
