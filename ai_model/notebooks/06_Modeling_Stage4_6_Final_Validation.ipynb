# %% [markdown]
# # 06. 사용주기 AI 4~6단계 최종 검증
#
# 이 노트북은 남은 단계를 한 번에 실행한다.
#
# 1. 4단계: 2단계 상위 모델 산출물과 단순 앙상블 비교
# 2. 추가 검증: 취득일자 기준 최근 20% holdout 검증
# 3. 5단계: Prediction 대상 후처리 smoke test
# 4. 6단계: 최종 후보 모델 리포트 및 서버 호환성 점검
#
# 실제 서버 배포 경로(`rf_final_model.pkl`)는 이 노트북에서 덮어쓰지 않는다.

# %%
# %run ai_model/experiments/run_stage4_6_final_validation.py
